# %%
import pymysql

# %%
conn=pymysql.connect(host="localhost",user="root",password="",db="hotel")

# %%
a=conn.cursor()

# %%
sql="select * from user4;"

# %%
a.execute(sql)
# Out:
# 26

# %%
import pandas as pd
d=a.fetchall()

# %%
d=[list(i) for i in d]

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#                 0                        1           2          3    4  \
# 0           mayur                      qsa         312       asfa    3
# 1           mayur                    haxch         123      sdjas   23
# 2           mayur                    haxch         123      sdjas   23
# 3           mayur                    haxch         123      sdjas   23
# 4           mayur                    haxch         123      sdjas   23
# 5           mayur                      afa         123        asd  124
# 6           mayur                      afa         123        asd  124
# 7           mayur                      afa         123        asd  124
# 8           mayur                      afa         123        asd  124
# 9           mayur                      afa         123        asd  124
# 10          mayur                      afa         123        asd  124
# 11        Shubham                   SP@hbc          54               0
# ...
